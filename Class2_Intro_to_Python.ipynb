# %%
IDE - Integrated Development Environment

# %%
Anaconda ---> Jupyter Notebook , Spyder , Jupyter Lab , AWS

# %% [markdown]
# # What is Python?
# - Python is a High level , Dynamically typed Programming Language

# %% [markdown]
# # What is Programming Language?
# - It is the way of communication between Humans and Machines

# %%
print(10+50)
# Out:
# 60

# %%
 # Dynamically typed

a = 10 
ex --> Python

# %%
 # Statically typed

int b ; # defining the variable type
b = 20 # declaring the value
ex --> Java , C programming

# %%
# Levels of languages
1 High level 
2 Low level Language
3 Middle Level Language

# %%
# High level - (More Understandable by Humans)
Hig level of Abstraction which means it is User friendly
Example - Python , Java , C++

# %%
# Low level Language (More Understandable by Machines)
Low level of Abstraction, which means it is not user friendly
Example - CNC , NC , Assembly Language

# %%
# Middle Level Language
- it falls between Low level and High level language 
example - C programming

# %%
embedded C - Machines
C - software develop

# %% [markdown]
# # Python is an Interpreted Language or compiled Language?
# - Python is both Interpreted language as well as Compiled language
# PVM
# Clanguage ,pypy ,jpython

# %%
10 + 20 + 50

# %%
print("Hello")

# %%
# History of Python
- in late 1980's it was developed
- Guido van Rossum

# %%
import sys
sys.version
# Out:
# '3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]'

# %%
print("Hello")
print()
print("World")
# Out:
# Hello
#
# World

# %%
a = 10
b = 20
a
# Out:
# 10

# %% [markdown]
# # Extensions of python files
# - 1 ---> .py
# - 2 ---> .ipynb

# %% [markdown]
# # Ways of Executing a python file
# - Normal Execution
# - Python Interpretor using Terminal
# - python file using Teminal(.py)

# %%
print(10+90)
# Out:
# 100

# %%
pwd
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\29Sept24'

# %% [markdown]
# # Components of Python
# - Literals
# - Constants
# - identifiers
# - Reserved Words or keywords
# - Statements and Expressions
# - Blocks and indentation
# - Comments

# %%
a = 10
print("Hello")
print(a+b)

# %% [markdown]
# # Literals - any value you see in python is a literal
# - int
# - float
# - str
# - complex
# - bool
# - None
# - list

# %%
a = 10

# %%
b = 99.5

# %%
c = "hello"

# %% [markdown]
# # Constants - these are te values that can not be changed
# convention ----> all constants should use UPPER case letters

# %%
PI = 3.14

# %%
PI
# Out:
# 3.14

# %%
PI = 99

# %%
PI
# Out:
# 99

# %%
G = 9.81

# %%
G
# Out:
# 9.81

# %% [markdown]
# # identifiers (Variables) - these are the names given to the Literals

# %%
# Rules to declare an identifier
Allowed Char are A-Z , a-z , 0-9 , _
Can not start with Numbers
Identifiers should not use any Reserved words
Identifiers are case sensitive
Specail characters are not allowed except _

# %%
a = 20

# %%
ABC = 55

# %%
ABC
# Out:
# 55

# %%
a1 = 90
a2 = 45
Aa123 = 99
abc_ = 99.5

# %%
abc_
# Out:
# 99.5

# %%
123abc = 98
# Out:
#   Cell In[66], line 1
#     123abc = 98
#       ^
# SyntaxError: invalid decimal literal

# %%
abc = 100

# %%
ABC = 555

# %%
ABC
# Out:
# 555

# %%
abc
# Out:
# 100

# %%
$abc = 345
# Out:
#   Cell In[78], line 1
#     $abc = 345
#     ^
# SyntaxError: invalid syntax

# %%
_abc = 345

# %%
_abc
# Out:
# 345

# %%
abc = "$567"

# %%
ABC$ = 000
# Out:
#   Cell In[88], line 1
#     ABC$ = 000
#        ^
# SyntaxError: invalid syntax

# %%
&*( = 99
# Out:
#   Cell In[90], line 1
#     &*( = 99
#     ^
# SyntaxError: invalid syntax

# %%
a = 10
A =30

# %%
A

# %%
identifier(variable)<---------------a = 200--------------> Literal

# %%
# !abc = 0 # Invalid
23ccx = 99 # Invalid
abcABC = 876 # valid
abc_ABC = 000 # valid
a%bc = 78 # invalid
a = # invalid
a@ == 21 # Invalid

# %% [markdown]
# # Reserved Words or keywords
# - In python there are certain words that carry a special meaning

# %%
print(10)
# Out:
# 10

# %%
print(20)
# Out:
# 20

# %%
print("Hello")
# Out:
# Hello

# %%
print = 80

# %%
print(30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 print(30)
#
# TypeError: 'int' object is not callable

# %%
80(30)
# Out:
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14444\3026218668.py:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   80(30)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 80(30)
#
# TypeError: 'int' object is not callable

# %%
print("hello")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 print("hello")
#
# TypeError: 'int' object is not callable

# %%
print(10)
# Out:
# 10

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %% [markdown]
# # Statements and Expressions

# %%
a = 299 # Statement

# %%
b = 270+30 # Expression

# %%
sum = 
str
list
tuple
if
else

# %%
pi = 3.14

# %%
PI = 3.14

# %%
import matplotlib.pyplot as plt
a = [1,2,3]
b = [2004,2005,2006]
plt.plot(b,a)
