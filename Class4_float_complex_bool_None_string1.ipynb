# %% [markdown]
# # Float data type
# - Any positive or negative number with decimal value

# %%
a = 66.5

# %%
type(a)
# Out:
# float

# %%
b = -97.6543
type(b)
# Out:
# float

# %%
# Operations on Float
# Aritmetic operations
# comparision operations
# Equality operations
# Logical operations
# assignment operations

# %%
# identity operations
is 
is not

# %%
a = 10
b = 10

# %%
id(a)
# Out:
# 140713717545688

# %%
id(b)
# Out:
# 140713717545688

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
var1 = 1.1
var2 = 1.1

# %%
id(var1)
# Out:
# 1388248633008

# %%
id(var2)
# Out:
# 1388204879280

# %% [markdown]
# # Note - Memory Reusability is not applicable on float

# %%
var1 is var2
# Out:
# False

# %%
var2 is not var1
# Out:
# True

# %% [markdown]
# # Complex Data type
# - Any number that can be represented in the form of a+bj
# - where
# - a ---> Real number
# - b ---> imaginary number

# %%
c = 12+3j

# %%
type(c)
# Out:
# complex

# %%
d = 7.5-8j
d
# Out:
# (7.5-8j)

# %%
type(d)
# Out:
# complex

# %%
a = 7.1
b = 7.1

# %%
a is b
# Out:
# False

# %%
id(a)
# Out:
# 1388228565392

# %%
id(b)
# Out:
# 1388248634288

# %%
a = 1+12j

# %%
type(a)
# Out:
# complex

# %%
a.real
# Out:
# 1.0

# %%
d.real
# Out:
# 7.5

# %%
a.imag
# Out:
# 12.0

# %%
d.imag
# Out:
# -8.0

# %%
f = 0.0+0j

# %%
f
# Out:
# 0j

# %%
type(f)
# Out:
# complex

# %%
f.real
# Out:
# 0.0

# %%
f.imag
# Out:
# 0.0

# %%
# operations on Complex numbers

# %%
# arithmetic Operation
# Logical operations
# Assignment operation
# Equality operation
# identity operation
###
# comaprision operation is not applicable on complex numbers

# %%
a
# Out:
# (1+12j)

# %%
c
# Out:
# (12+3j)

# %%
a+c
# Out:
# (13+15j)

# %%
13+15j

# %%
a > c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 a > c
#
# TypeError: '>' not supported between instances of 'complex' and 'complex'

# %%
a is a
# Out:
# True

# %%
id(a)
# Out:
# 1388248634352

# %%
id(a)
# Out:
# 1388248634352

# %%
a = 1+12J
b = 1+12j

# %%
id(a)
# Out:
# 1388272098320

# %%
id(b)
# Out:
# 1388272099216

# %%
a is b
# Out:
# False

# %%
1-12j
# Out:
#   Cell In[98], line 1
#     1:12j
#     ^
# SyntaxError: illegal target for annotation

# %% [markdown]
# # None Type
# None is used to represent the missing value

# %%
a = None

# %%
a

# %%
type(a)
# Out:
# NoneType

# %%
print(a)
# Out:
# None

# %%
b = None

# %%
a is b
# Out:
# True

# %% [markdown]
# # Boolean data type

# %%
True 
False

# %%
a = True
b = True

# %%
type(a)
# Out:
# bool

# %%
True and True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
1 + 1
# Out:
# 2

# %%
True + True
# Out:
# 2

# %%
0+0
# Out:
# 0

# %%
False + False
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True - True
# Out:
# 0

# %%
a
# Out:
# True

# %%
b
# Out:
# True

# %%
id(a)
# Out:
# 140713716419456

# %%
id(b)
# Out:
# 140713716419456

# %%
a = 50
b = 40
if a==50 and b== 40:
    print("a is 50 b is 40")

# %%
a
# Out:
# True

# %%
d = 1

# %%
id(a)
# Out:
# 140713716419456

# %%
id(d)
# Out:
# 140713717545400

# %%
# Type Casting
# what is Type casting?
- Converting one data type to another data type is type casting

# %%
a = 40

# %%
type(a)
# Out:
# int

# %%
b = float(a)
b
# Out:
# 40.0

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
complex(a)
# Out:
# (40+0j)

# %%
bool(500)
# Out:
# True

# %%
0
1
i

# %%
bool(0)
# Out:
# False

# %%
bool(-90)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
s = "1.25"

# %%
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 int(s)
#
# ValueError: invalid literal for int() with base 10: '1.25'

# %%
f = float(s)

# %%
f
# Out:
# 1.25

# %%
int(f)
# Out:
# 1

# %%
c = int(float(s))

# %%
c
# Out:
# 1

# %%
complex(c)
# Out:
# (1+0j)

# %%
f
# Out:
# 1.25

# %%
c = complex(f)

# %%
c
# Out:
# (1.25+0j)

# %%
10:55
11:10
break

# %%
a = 10
if a==10:
    print("a is 10")

# %%
a = 10
a==10
# Out:
# True

# %%
a1=1+10j
b1=1+10j
a1 is b1
# Out:
# False

# %%
a1.real
# Out:
# 1.0

# %%
"1.25"

# %%
a = 10+5j

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[232], line 1
# ----> 1 int(a)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(a.real)
# Out:
# 10

# %% [markdown]
# # String
# anything that is written inside
# - ' '
# - " "
# - ''' '''
# - """ """

# %%
abc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 abc
#
# NameError: name 'abc' is not defined

# %%
s = 'abc'

# %%
s
# Out:
# 'abc'

# %%
type(s)
# Out:
# str

# %%
"abc"
# Out:
# 'abc'

# %%
s = 'this is python's class'
# Out:
#   Cell In[254], line 1
#     s = 'this is python's class'
#                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s = "this is python's class"

# %%
s
# Out:
# "this is python's class"

# %%
s = "this is '''python''' class"

# %%
s
# Out:
# "this is '''python''' class"

# %%
s = '''this is '''python''' class'''
# Out:
#   Cell In[266], line 1
#     s = '''this is '''python''' class'''
#                       ^
# SyntaxError: invalid syntax

# %%
s = """this is 
'''python'''
class"""

# %%
print(s)
# Out:
# this is
# '''python'''
# class

# %%
s = ''' """Hello"""$%$^%&**(*((*& we are 
learning 
python'''

# %%
print(s)
# Out:
#  """Hello"""$%$^%&**(*((*& we are
# learning
# python

# %% [markdown]
# # Input and Output functions

# %% [markdown]
# # Input
# - Input is a function that is used to take the user input in python

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
a = input("Enter the amount you want to withdraw: ")
b = input("Enter a second number: ")
# Out:
# Enter the amount you want to withdraw:  abc
# Enter a second number:  123

# %%
a
# Out:
# 'abc'

# %%
b
# Out:
# '123'

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# str

# %%
a = int(input("Enter the amount you want to withdraw: "))
b = float(input("Enter a second number: "))
# Out:
# Enter the amount you want to withdraw:  1234
# Enter a second number:  2345

# %%
a
# Out:
# 1234

# %%
b
# Out:
# 2345.0

# %%
a = input("Enter the username: ")
b = float(input("Enter a second number: "))
# Out:
# Enter the username:  100$%^&
# Enter a second number:  12343

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[352], line 1
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: '100$%^&'

# %%
a
# Out:
# '100$%^&'

# %%
print(dir(__builtin__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
a = input("Enter anything")
# Out:
# Enter anything 2.345

# %%
a
# Out:
# '2.345'

# %%
type(a)
# Out:
# str

# %% [markdown]
# # eval
# - eval is function that is used along with input function which automaticall detects the data type enterd by the user

# %%
a = eval(input("Enter anything "))
print(a)
type(a)
# Out:
# Enter anything  [1,2,3,4]
# [1, 2, 3, 4]
# list

# %%
a = eval(input("Enter anything "))
# Out:
# Enter anything  "abc"

# %%
a
# Out:
# 2.345

# %%
type(a)
# Out:
# float

# %%
a = int(input("enter your marks"))

user enters 45.56
print(a)

will the above code work?
or we have to use this:
a = int(float((input(“enter your marks”)))
as in type cast we have not conerted str directly to float.

# %%
int(45.56)
# Out:
# 45

# %% [markdown]
# # Output Function

# %%
print() --- is the output function in python

# %%
a = 10
b = 20
a
c = 40
b
c
# Out:
# 40

# %%
a = 10
b = 20
print(a)
c = 40
print(b)
c
# Out:
# 10
# 20
# 40

# %%
a = 10
b = 20
c = 30
d = 40

# %%
print(a,b,c,d)
# Out:
# 10 20 30 40

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
print(a,b,c,d, sep="$$$$$$$$$$$$$$")
# Out:
# 10$$$$$$$$$$$$$$20$$$$$$$$$$$$$$30$$$$$$$$$$$$$$40

# %%
\n----> New line

# %%
print(a,end="===================")
print(b)
print(c)
print(d)
# Out:
# 10===================20
# 30
# 40

# %%
10===================20
30
40

# %%
print(a,b,sep="\n\n" ,end="%%%%")
print(a,c , sep=" " , end="\n")
print(d,c,b,end="%%%" , sep="---")
print(d,c,b,a, end="\n" , sep="ABCD")
print("hello")
# Out:
# 10
#
# 20%%%%10 30
# 40---30---20%%%40ABCD30ABCD20ABCD10
# hello

# %%
10

20%%%%10 30
40---30---20%%%40ABCD30ABCD20ABCD10

# %%
print(a, sep="%%%%%%")
# Out:
# 10

# %%
print(a,b, flush=True)
# Out:
# 10 20

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %% [markdown]
# # Format String

# %%
user1 = 1000
user2 = 30
"Value entered by user1 is  (value of user1) and value entered by user 2 is (value of user2) and the sum is user1+user2"
# Out:
# 'Value entered by user1 is  (value of user1) and value entered by user 2 is (value of user2) and the sum is user1+user2'

# %%
print("Value entered by user1 is",user1," and value entered by user 2 is ",user2," and the sum is ",user1+user2)
# Out:
# Value entered by user1 is 1000  and value entered by user 2 is  30  and the sum is  1030

# %%
# 1st way - f

# %%
user1 = int(input("Enter the 1st value: "))
user2 = int(input("Enter the second value: "))
print(f"Value entered by user1 is {user1} and value entered by user 2 is {user2} and the sum is {user1+user2}")
# Out:
# Enter the 1st value:  100
# Enter the second value:  200
# Value entered by user1 is 100 and value entered by user 2 is 200 and the sum is 300

# %%
# 1st way - .format()

# %%
user1 = int(input("Enter the 1st value: "))
user2 = int(input("Enter the second value: "))
print("Value entered by user1 is {} and value entered by user 2 is {} and the sum is {}".format(user1, user2 , user1+user2))
# Out:
# Enter the 1st value:  500
# Enter the second value:  300
# Value entered by user1 is 500 and value entered by user 2 is 300 and the sum is 800
